# %%
from aocd import get_data
import numpy as np

day22 = get_data(day=22,year=2021)

# %%
example = '''on x=-20..26,y=-36..17,z=-47..7
on x=-20..33,y=-21..23,z=-26..28
on x=-22..28,y=-29..23,z=-38..16
on x=-46..7,y=-6..46,z=-50..-1
on x=-49..1,y=-3..46,z=-24..28
on x=2..47,y=-22..22,z=-23..27
on x=-27..23,y=-28..26,z=-21..29
on x=-39..5,y=-6..47,z=-3..44
on x=-30..21,y=-8..43,z=-13..34
on x=-22..26,y=-27..20,z=-29..19
off x=-48..-32,y=26..41,z=-47..-37
on x=-12..35,y=6..50,z=-50..-2
off x=-48..-32,y=-32..-16,z=-15..-5
on x=-18..26,y=-33..15,z=-7..46
off x=-40..-22,y=-38..-28,z=23..41
on x=-16..35,y=-41..10,z=-47..6
off x=-32..-23,y=11..30,z=-14..3
on x=-49..-5,y=-3..45,z=-29..18
off x=18..30,y=-20..-8,z=-3..13
on x=-41..9,y=-7..43,z=-33..15
on x=-54112..-39298,y=-85059..-49293,z=-27449..7877
on x=967..23432,y=45373..81175,z=27513..53682'''
steps = [i.replace('on','1').replace('off','0').replace(' ',',').replace('x=','').replace('y=','').replace('z=','').replace('..',',').split(',') for i in example.split('\n')]
steps = [[int(j) for j in i] for i in steps]
steps
# Out:
# [[1, -20, 26, -36, 17, -47, 7],
#  [1, -20, 33, -21, 23, -26, 28],
#  [1, -22, 28, -29, 23, -38, 16],
#  [1, -46, 7, -6, 46, -50, -1],
#  [1, -49, 1, -3, 46, -24, 28],
#  [1, 2, 47, -22, 22, -23, 27],
#  [1, -27, 23, -28, 26, -21, 29],
#  [1, -39, 5, -6, 47, -3, 44],
#  [1, -30, 21, -8, 43, -13, 34],
#  [1, -22, 26, -27, 20, -29, 19],
#  [0, -48, -32, 26, 41, -47, -37],
#  [1, -12, 35, 6, 50, -50, -2],
#  [0, -48, -32, -32, -16, -15, -5],
#  [1, -18, 26, -33, 15, -7, 46],
#  [0, -40, -22, -38, -28, 23, 41],
#  [1, -16, 35, -41, 10, -47, 6],
#  [0, -32, -23, 11, 30, -14, 3],
#  [1, -49, -5, -3, 45, -29, 18],
#  [0, 18, 30, -20, -8, -3, 13],
#  [1, -41, 9, -7, 43, -33, 15],
#  [1, -54112, -39298, -85059, -49293, -27449, 7877],
#  [1, 967, 23432, 45373, 81175, 27513, 53682]]

# %%
cubes = np.zeros((101,101,101))
for i in steps:
    cubes[i[1]+50:i[2]+51,i[3]+50:i[4]+51,i[5]+50:i[6]+51] = i[0]

# %%
np.sum(cubes)
# Out:
# 547648.0

# %%
steps = [i.replace('on','1').replace('off','0').replace(' ',',').replace('x=','').replace('y=','').replace('z=','').replace('..',',').split(',') for i in day22.split('\n')]
steps = [[int(j) for j in i] for i in steps]
steps
# Out:
# [[1, -4, 48, -30, 24, -39, 15],
#  [1, -19, 33, -15, 29, -4, 42],
#  [1, -1, 49, -14, 38, -27, 20],
#  [1, -28, 16, -16, 36, -21, 27],
#  [1, -23, 27, -26, 20, -23, 22],
#  [1, -8, 43, -10, 43, -21, 30],
#  [1, -45, 4, -6, 47, -15, 33],
#  [1, -22, 22, -6, 45, -29, 19],
#  [1, -30, 18, -47, -3, -24, 22],
#  [1, -6, 43, -37, 8, -19, 27],
#  [0, 18, 28, -15, 4, 32, 49],
#  [1, -2, 45, -17, 35, -15, 34],
#  [0, -49, -33, -49, -31, -10, 5],
#  [1, -31, 21, -12, 34, -48, 6],
#  [0, -38, -27, -44, -25, -17, -4],
#  [1, -21, 32, -9, 45, -18, 33],
#  [0, -14, 3, -10, -1, -40, -29],
#  [1, -30, 16, -13, 34, -4, 45],
#  [0, 24, 34, 13, 32, -38, -25],
#  [1, -27, 26, -14, 38, -24, 22],
#  [1, 35544, 55136, 51736, 62748, -58537, -33425],
#  [1, 33690, 50869, -78828, -40948, -44269, -23196],
#  [1, 65407, 77846, -1962, 21102, 30745, 35336],
#  [1, 43820, 63036, 45669, 68304, -27802, -19946],
#  [1, -80968, -79217, -15189, 550, -20396, -2177],
#  [1, 22543, 55131, -50184, -36252, 46098, 64106],
# ...

# %%
cubes = np.zeros((101,101,101))
for i in steps:
    cubes[i[1]+50:i[2]+51,i[3]+50:i[4]+51,i[5]+50:i[6]+51] = i[0]
np.sum(cubes)
# Out:
# 547648.0

# %% [markdown]
# Ugh, I copied the ".0" part and it didn't accept the answer at first.

# %%
import pandas as pd
df = pd.DataFrame(data=steps,columns=['value','xmin','xmax','ymin','ymax','zmin','zmax'])

# %%
df
# Out:
#      value   xmin   xmax   ymin   ymax   zmin   zmax
# 0        1     -4     48    -30     24    -39     15
# 1        1    -19     33    -15     29     -4     42
# 2        1     -1     49    -14     38    -27     20
# 3        1    -28     16    -16     36    -21     27
# 4        1    -23     27    -26     20    -23     22
# ..     ...    ...    ...    ...    ...    ...    ...
# 415      1  51594  75047  26992  37723 -11584   -911
# 416      1 -45309 -20784  44096  70601 -52394 -33571
# 417      0  16870  35569  13219  31860  69493  87370
# 418      1 -22983 -16966  59778  70013  26803  46876
# 419      1  33076  50573 -80935 -61509 -30866  -2196
#
# [420 rows x 7 columns]

# %%
df.merge(df,how='outer')
# Out:
#      value   xmin   xmax   ymin   ymax   zmin   zmax
# 0        1     -4     48    -30     24    -39     15
# 1        1    -19     33    -15     29     -4     42
# 2        1     -1     49    -14     38    -27     20
# 3        1    -28     16    -16     36    -21     27
# 4        1    -23     27    -26     20    -23     22
# ..     ...    ...    ...    ...    ...    ...    ...
# 415      1  51594  75047  26992  37723 -11584   -911
# 416      1 -45309 -20784  44096  70601 -52394 -33571
# 417      0  16870  35569  13219  31860  69493  87370
# 418      1 -22983 -16966  59778  70013  26803  46876
# 419      1  33076  50573 -80935 -61509 -30866  -2196
#
# [420 rows x 7 columns]
